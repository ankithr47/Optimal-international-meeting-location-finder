# %%
import polars as pl
import json
import os
import datetime

# %%
#WE WOULD NEED A JSON_FILE AS AN INPUT
json_file='/Users/ankithrangan/Downloads/example.json'


#selecting attendees from json file
with open(json_file,'r') as file:
    data=json.load(file)
attendees=data['attendees']



#example attendees
"""
attendees={
		"Mumbai": 2,
		"Shanghai": 3,
		"Hong Kong": 1,
		"Singapore": 2,
		"Sydney": 2}
"""
# Out:
# '\nattendees={\n\t\t"Mumbai": 2,\n\t\t"Shanghai": 3,\n\t\t"Hong Kong": 1,\n\t\t"Singapore": 2,\n\t\t"Sydney": 2}\n'

# %%
# Read the CSV file

a = 5

# Open and read the JSON file
def file_list(json_file):
    # Read the JSON file
    with open(json_file, "r") as file:
        data = json.load(file)
    start_date_str = data["availability_window"]["start"]
    end_date_str = data["availability_window"]["end"]

    start_date = datetime.datetime.strptime(start_date_str.replace("Z", ""), "%Y-%m-%dT%H:%M:%S")
    end_date = datetime.datetime.strptime(end_date_str.replace("Z", ""), "%Y-%m-%dT%H:%M:%S")

    files = []

    # Loop from start to end date within availability window
    current_date = start_date - datetime.timedelta(days=a)
    while current_date.date() <= end_date.date():
        # For each file, construct path like ChallengeData/schedules/2025/12/10.csv
        file_path = os.path.join(
            "schedules",
            str(current_date.year),
            f"{current_date.month:02d}",
            f"{current_date.day:02d}.csv"
        )
        files.append(file_path)
        current_date += datetime.timedelta(days=1)

    return files

# example path: /Users/ankithrangan/Desktop/ChallengeData/schedules/2023/05/04.csv
#/Users/ankithrangan/Desktop/ChallengeData/schedules/2025/03/03.csv
schedule_files=[file_list(json_file)] #list of csv files
new_files = schedule_files[0]
new_files
# Out:
# ['schedules/2025/12/05.csv',
#  'schedules/2025/12/06.csv',
#  'schedules/2025/12/07.csv',
#  'schedules/2025/12/08.csv',
#  'schedules/2025/12/09.csv',
#  'schedules/2025/12/10.csv',
#  'schedules/2025/12/11.csv',
#  'schedules/2025/12/12.csv',
#  'schedules/2025/12/13.csv',
#  'schedules/2025/12/14.csv',
#  'schedules/2025/12/15.csv']

# %%
for i in range(len(new_files)):
    new_files[i] = f"/Users/ankithrangan/Desktop/ChallengeData/{new_files[i]}"
new_files
# Out:
# ['/Users/ankithrangan/Desktop/ChallengeData/schedules/2025/12/05.csv',
#  '/Users/ankithrangan/Desktop/ChallengeData/schedules/2025/12/06.csv',
#  '/Users/ankithrangan/Desktop/ChallengeData/schedules/2025/12/07.csv',
#  '/Users/ankithrangan/Desktop/ChallengeData/schedules/2025/12/08.csv',
#  '/Users/ankithrangan/Desktop/ChallengeData/schedules/2025/12/09.csv',
#  '/Users/ankithrangan/Desktop/ChallengeData/schedules/2025/12/10.csv',
#  '/Users/ankithrangan/Desktop/ChallengeData/schedules/2025/12/11.csv',
#  '/Users/ankithrangan/Desktop/ChallengeData/schedules/2025/12/12.csv',
#  '/Users/ankithrangan/Desktop/ChallengeData/schedules/2025/12/13.csv',
#  '/Users/ankithrangan/Desktop/ChallengeData/schedules/2025/12/14.csv',
#  '/Users/ankithrangan/Desktop/ChallengeData/schedules/2025/12/15.csv']

# %%
"""
from pathlib import Path
# If your file_list() returned relative paths like "schedules/2025/12/05.csv"
base = Path("/Users/ankithrangan/Desktop/ChallengeData")

# If schedule_files was [[...]], flatten it first:
flat_files = schedule_files[0] if isinstance(schedule_files[0], list) else schedule_files

# Build absolute paths and check existence
abs_paths = [base / Path(p.strip()) for p in flat_files]
existing = [str(p) for p in abs_paths if p.is_file()]
missing  = [str(p) for p in abs_paths if not p.is_file()]

if missing:
    print(f"Missing {len(missing)} files. First few:\n", "\n".join(missing[:5]))

if not existing:
    raise FileNotFoundError("No existing CSVs to read after filtering.")

# Combine them into a single DataFrame
schedules = pl.scan_csv(existing).collect()

"""


schedules=pl.scan_csv(new_files, infer_schema_length=10000).collect() #list of paths to access csv files (within availability)
schedules
#/Users/ankithrangan/Desktop/ChallengeData/schedules/2023/05/04.csv
# Out:
# shape: (2_353_407, 62)
# ┌─────────┬─────────────┬───────┬──────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ CARRIER ┆ CARRIER_CD_ ┆ FLTNO ┆ FLTSUFFX ┆ … ┆ ECONOMY_CL ┆ TOTAL_SEAT ┆ OAG_SCHEDU ┆ FILE_DATE  │
# │ ---     ┆ ICAO        ┆ ---   ┆ ---      ┆   ┆ ASS_SEATS  ┆ S          ┆ LE_FINGERP ┆ ---        │
# │ str     ┆ ---         ┆ i64   ┆ str      ┆   ┆ ---        ┆ ---        ┆ RINT       ┆ str        │
# │         ┆ str         ┆       ┆          ┆   ┆ i64        ┆ i64        ┆ ---        ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ str        ┆            │
# ╞═════════╪═════════════╪═══════╪══════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ RY      ┆ CJX         ┆ 2001  ┆ null     ┆ … ┆ 167        ┆ 175        ┆ f67d73459c ┆ 2025-10-28 │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 0934e5fa02 ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 08d4d3b197 ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ …          ┆            │
# │ RY      ┆ CJX         ┆ 2007  ┆ null     ┆ … ┆ 171        ┆ 171        ┆ 630793ba74 ┆ 2025-10-28 │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ c9ca962a0c ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 11442ba25f ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ …          ┆            │
# │ RY      ┆ CJX         ┆ 2065  ┆ null     ┆ … ┆ 171        ┆ 171        ┆ bcd619dac3 ┆ 2025-10-28 │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 712f222425 ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 264c9e97c4 ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ …          ┆            │
# │ RY      ┆ CJX         ┆ 2083  ┆ null     ┆ … ┆ 167        ┆ 175        ┆ 3137ca4cef ┆ 2025-10-28 │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 6f73e5b46f ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 7e6af913b1 ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ …          ┆            │
# │ RY      ┆ CJX         ┆ 6625  ┆ null     ┆ … ┆ 179        ┆ 185        ┆ eb2f9bb46a ┆ 2025-10-28 │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 3afc4bbeaa ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ aa347ddfbc ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ …          ┆            │
# │ …       ┆ …           ┆ …     ┆ …        ┆ … ┆ …          ┆ …          ┆ …          ┆ …          │
# │ EK      ┆ UAE         ┆ 6257  ┆ null     ┆ … ┆ 48         ┆ 76         ┆ 8984e04e16 ┆ 2025-10-28 │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ c3c671e74e ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ ffdd790529 ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ …          ┆            │
# │ EK      ┆ UAE         ┆ 9070  ┆ T        ┆ … ┆ null       ┆ null       ┆ ecec3c9dac ┆ 2025-10-28 │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 8f4b0a96d9 ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 5637266c07 ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ …          ┆            │
# │ EK      ┆ UAE         ┆ 9075  ┆ T        ┆ … ┆ null       ┆ null       ┆ 5ba853a8d3 ┆ 2025-10-28 │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 961a769a01 ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 8351c43bc6 ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ …          ┆            │
# │ TN      ┆ THT         ┆ 2334  ┆ null     ┆ … ┆ 138        ┆ 178        ┆ 46af923c3e ┆ 2025-10-28 │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 002448dfae ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 35e1f4fad4 ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ …          ┆            │
# │ TN      ┆ THT         ┆ 2462  ┆ null     ┆ … ┆ 64         ┆ 76         ┆ f48371a96c ┆ 2025-10-28 │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 0585c5e30f ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 6576ca7ebd ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ …          ┆            │
# └─────────┴─────────────┴───────┴──────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %%
airport_dictionary = {
    'Mumbai': ['BOM'],
    'London': ['LHR', 'LGW', 'LTN', 'STN'],
    'Paris': ['CDG', 'ORY', 'BVA'],
    'Hong Kong': ['HKG'],
    'Singapore': ['SIN'],
    'Shanghai': ['PVG', 'SHA'],
    'Dubai': ['DXB'],
    'Zürich': ['ZRH'],
    'Geneva': ['GVA'],
    'Aarhus': ['AAR'],
    'Sydney': ['SYD'],
    'Wroclaw': ['WRO'],
    'Budapest': ['BUD']
}

#adds corresponding country code to 'target codes'
target_codes = set()
for city in attendees.keys():
    if city in airport_dictionary:
        target_codes.update(airport_dictionary[city])

#filter relevant airports (ie in target_codes)
filter_expression = (
    (pl.col("DEPCITY").is_in(target_codes)) | 
    (pl.col("ARRCITY").is_in(target_codes))
)

filtered_schedules = schedules.filter(filter_expression) #gives all rows with airports mentioned in the input
filtered_schedules
# Out:
# shape: (124_200, 62)
# ┌─────────┬─────────────┬───────┬──────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ CARRIER ┆ CARRIER_CD_ ┆ FLTNO ┆ FLTSUFFX ┆ … ┆ ECONOMY_CL ┆ TOTAL_SEAT ┆ OAG_SCHEDU ┆ FILE_DATE  │
# │ ---     ┆ ICAO        ┆ ---   ┆ ---      ┆   ┆ ASS_SEATS  ┆ S          ┆ LE_FINGERP ┆ ---        │
# │ str     ┆ ---         ┆ i64   ┆ str      ┆   ┆ ---        ┆ ---        ┆ RINT       ┆ str        │
# │         ┆ str         ┆       ┆          ┆   ┆ i64        ┆ i64        ┆ ---        ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ str        ┆            │
# ╞═════════╪═════════════╪═══════╪══════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 3U      ┆ CSC         ┆ 4522  ┆ null     ┆ … ┆ 156        ┆ 164        ┆ 80007267d1 ┆ 2025-10-28 │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ abffc3f65c ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 8724007796 ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ …          ┆            │
# │ 3U      ┆ CSC         ┆ 4610  ┆ null     ┆ … ┆ 156        ┆ 164        ┆ 25f4bc81cc ┆ 2025-10-28 │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 6dfc2de3d4 ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ fcf2b48c22 ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ …          ┆            │
# │ AA      ┆ AAL         ┆ 7297  ┆ null     ┆ … ┆ 162        ┆ 174        ┆ e2803035b4 ┆ 2025-10-28 │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ c79e9873ed ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 999d85e16e ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ …          ┆            │
# │ MU      ┆ CES         ┆ 3868  ┆ null     ┆ … ┆ 156        ┆ 164        ┆ bf57e4ad46 ┆ 2025-10-28 │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ cad9d7c873 ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 220263a3cc ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ …          ┆            │
# │ MU      ┆ CES         ┆ 5101  ┆ null     ┆ … ┆ 258        ┆ 316        ┆ a3cb09476c ┆ 2025-10-28 │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 9d2b1c6d9c ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 32be150fca ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ …          ┆            │
# │ …       ┆ …           ┆ …     ┆ …        ┆ … ┆ …          ┆ …          ┆ …          ┆ …          │
# │ VS      ┆ VIR         ┆ 8610  ┆ null     ┆ … ┆ 232        ┆ 232        ┆ 45a7a42b04 ┆ 2025-10-28 │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 8541dd1b3a ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 16ab8e38ce ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ …          ┆            │
# │ ZH      ┆ CSZ         ┆ 4573  ┆ null     ┆ … ┆ 356        ┆ 392        ┆ a22b1c6b53 ┆ 2025-10-28 │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 32b072f39c ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ d9c43b0459 ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ …          ┆            │
# │ ZH      ┆ CSZ         ┆ 5019  ┆ null     ┆ … ┆ 156        ┆ 164        ┆ 93ada24be5 ┆ 2025-10-28 │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 85cbe85f10 ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 9285200737 ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ …          ┆            │
# │ CX      ┆ CPA         ┆ 5598  ┆ null     ┆ … ┆ 230        ┆ 230        ┆ ccb0053991 ┆ 2025-10-28 │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 46d617cf05 ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 33f51655fd ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ …          ┆            │
# │ CA      ┆ CCA         ┆ 1021  ┆ null     ┆ … ┆ null       ┆ null       ┆ 931c18be8d ┆ 2025-10-28 │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 0c0489d029 ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ 7e74d374ce ┆            │
# │         ┆             ┆       ┆          ┆   ┆            ┆            ┆ …          ┆            │
# └─────────┴─────────────┴───────┴──────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %%
filtered_schedules= filtered_schedules.with_columns(
    FLIGHT_DURATION = (
        pl.col("SCHEDULED_ARRIVAL_DATE_TIME_UTC").str.to_datetime() -
        pl.col("SCHEDULED_DEPARTURE_DATE_TIME_UTC").str.to_datetime()
    )
)

# 2. Select only the columns you want
final_df = filtered_schedules.select(
    "DEPCITY",
    "ARRCITY",
    "SCHEDULED_DEPARTURE_DATE_TIME_LOCAL",
    "SCHEDULED_ARRIVAL_DATE_TIME_LOCAL",
    "FLIGHT_DURATION"  # The new column we just made
)

# Display the final result
print(final_df.unique())
# Out:
# shape: (64_247, 5)
# ┌─────────┬─────────┬──────────────────────────────┬─────────────────────────────┬─────────────────┐
# │ DEPCITY ┆ ARRCITY ┆ SCHEDULED_DEPARTURE_DATE_TIM ┆ SCHEDULED_ARRIVAL_DATE_TIME ┆ FLIGHT_DURATION │
# │ ---     ┆ ---     ┆ E_…                          ┆ _LO…                        ┆ ---             │
# │ str     ┆ str     ┆ ---                          ┆ ---                         ┆ duration[μs]    │
# │         ┆         ┆ str                          ┆ str                         ┆                 │
# ╞═════════╪═════════╪══════════════════════════════╪═════════════════════════════╪═════════════════╡
# │ HAN     ┆ SHA     ┆ 2025-12-08 02:50:00.000      ┆ 2025-12-08 06:50:00.000     ┆ 3h              │
# │ SHA     ┆ OSA     ┆ 2025-12-15 11:30:00.000      ┆ 2025-12-15 15:00:00.000     ┆ 2h 30m          │
# │ MEL     ┆ SYD     ┆ 2025-12-14 07:00:00.000      ┆ 2025-12-14 08:35:00.000     ┆ 1h 35m          │
# │ SHA     ┆ DLC     ┆ 2025-12-05 20:05:00.000      ┆ 2025-12-05 21:55:00.000     ┆ 1h 50m          │
# │ BOM     ┆ CCU     ┆ 2025-12-05 20:15:00.000      ┆ 2025-12-05 22:50:00.000     ┆ 2h 35m          │
# │ …       ┆ …       ┆ …                            ┆ …                           ┆ …               │
# │ GOI     ┆ BOM     ┆ 2025-12-09 19:40:00.000      ┆ 2025-12-09 21:00:00.000     ┆ 1h 20m          │
# │ HKG     ┆ BKK     ┆ 2025-12-08 21:00:00.000      ┆ 2025-12-08 23:15:00.000     ┆ 3h 15m          │
# │ SHA     ┆ CTU     ┆ 2025-12-10 08:55:00.000      ┆ 2025-12-10 12:15:00.000     ┆ 3h 20m          │
# │ HKG     ┆ TYO     ┆ 2025-12-10 03:45:00.000      ┆ 2025-12-10 08:40:00.000     ┆ 3h 55m          │
# │ SIN     ┆ YVR     ┆ 2025-12-13 08:50:00.000      ┆ 2025-12-13 06:50:00.000     ┆ 14h             │
# └─────────┴─────────┴──────────────────────────────┴─────────────────────────────┴─────────────────┘

# %%
emissions2 = pl.read_csv("/Users/ankithrangan/Desktop/ChallengeData/emissions.csv")
emissions2
# Out:
# shape: (328_872, 27)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ SCHEDULED ┆ CARRIER_C ┆ OUTBOUND_ ┆ SERVICE_S ┆ … ┆ ESTIMATED ┆ MISSING_R ┆ LOAD_DATE ┆ IS_OPERA │
# │ _FLIGHT_L ┆ ODE       ┆ CODE      ┆ UFFIX     ┆   ┆ _CO2_TOTA ┆ EFERENCE_ ┆ ---       ┆ TING     │
# │ EG_PK     ┆ ---       ┆ ---       ┆ ---       ┆   ┆ L_TONNES  ┆ FLIGHT_TI ┆ str       ┆ ---      │
# │ ---       ┆ str       ┆ str       ┆ str       ┆   ┆ ---       ┆ MES       ┆           ┆ bool     │
# │ str       ┆           ┆           ┆           ┆   ┆ f64       ┆ ---       ┆           ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆ bool      ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 921991ff5 ┆ 0B        ┆ null      ┆ null      ┆ … ┆ 9.857     ┆ false     ┆ 2024-12-0 ┆ true     │
# │ 1c02a70ff ┆           ┆           ┆           ┆   ┆           ┆           ┆ 5         ┆          │
# │ 6c09cfb69 ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 425…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 9a8f33c59 ┆ 0B        ┆ null      ┆ null      ┆ … ┆ 10.941    ┆ false     ┆ 2024-12-0 ┆ true     │
# │ f1cd15bea ┆           ┆           ┆           ┆   ┆           ┆           ┆ 5         ┆          │
# │ a23ad1641 ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 78d…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 3da312f36 ┆ 0B        ┆ null      ┆ null      ┆ … ┆ 9.857     ┆ false     ┆ 2024-12-0 ┆ true     │
# │ 2a107e999 ┆           ┆           ┆           ┆   ┆           ┆           ┆ 5         ┆          │
# │ f0de6632e ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 647…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 263319d49 ┆ 0B        ┆ null      ┆ null      ┆ … ┆ 10.941    ┆ false     ┆ 2024-12-0 ┆ true     │
# │ 997ab511a ┆           ┆           ┆           ┆   ┆           ┆           ┆ 5         ┆          │
# │ b864b7cd0 ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 126…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ d4b79b0fa ┆ 0B        ┆ null      ┆ null      ┆ … ┆ 13.294    ┆ false     ┆ 2024-12-0 ┆ true     │
# │ 0f7d633e7 ┆           ┆           ┆           ┆   ┆           ┆           ┆ 5         ┆          │
# │ 0c0bd9bdb ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 35e…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ f49b59b65 ┆ ZV        ┆ null      ┆ null      ┆ … ┆ null      ┆ true      ┆ 2024-12-0 ┆ true     │
# │ 77b132f08 ┆           ┆           ┆           ┆   ┆           ┆           ┆ 5         ┆          │
# │ 6cb68c1cd ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 67a…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ac75acf7e ┆ ZV        ┆ null      ┆ null      ┆ … ┆ null      ┆ true      ┆ 2024-12-0 ┆ true     │
# │ 1b5151c91 ┆           ┆           ┆           ┆   ┆           ┆           ┆ 5         ┆          │
# │ 0635a3493 ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 246…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 07977f043 ┆ ZV        ┆ null      ┆ null      ┆ … ┆ null      ┆ true      ┆ 2024-12-0 ┆ true     │
# │ 39f9b5463 ┆           ┆           ┆           ┆   ┆           ┆           ┆ 5         ┆          │
# │ 17ae1d459 ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ec9…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 81f2d2d5a ┆ ZV        ┆ null      ┆ null      ┆ … ┆ null      ┆ true      ┆ 2024-12-0 ┆ true     │
# │ 14db58e00 ┆           ┆           ┆           ┆   ┆           ┆           ┆ 5         ┆          │
# │ 3f06b78e8 ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 847…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 0a7acd584 ┆ ZV        ┆ null      ┆ null      ┆ … ┆ null      ┆ true      ┆ 2024-12-0 ┆ true     │
# │ 11f00e3cd ┆           ┆           ┆           ┆   ┆           ┆           ┆ 5         ┆          │
# │ 837ec502b ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 7b6…      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
#eliminate flight code column
emissions2 = emissions2.drop("SCHEDULED_FLIGHT_LEG_PK", "CARRIER_CODE", "OUTBOUND_CODE", "SERVICE_SUFFIX", "LOAD_DATE", "SCHEDULED_DEPARTURE_DATE")
emissions2
# Out:
# shape: (328_872, 21)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ FLIGHT_NU ┆ DEPARTURE ┆ ARRIVAL_A ┆ AIRCRAFT_ ┆ … ┆ ESTIMATED ┆ ESTIMATED ┆ MISSING_R ┆ IS_OPERA │
# │ MBER      ┆ _AIRPORT  ┆ IRPORT    ┆ TYPE      ┆   ┆ _CO2_TAXI ┆ _CO2_TOTA ┆ EFERENCE_ ┆ TING     │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ _IN_TONNE ┆ L_TONNES  ┆ FLIGHT_TI ┆ ---      │
# │ i64       ┆ str       ┆ str       ┆ str       ┆   ┆ S         ┆ ---       ┆ MES       ┆ bool     │
# │           ┆           ┆           ┆           ┆   ┆ ---       ┆ f64       ┆ ---       ┆          │
# │           ┆           ┆           ┆           ┆   ┆ f64       ┆           ┆ bool      ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 761       ┆ CGK       ┆ SUB       ┆ 738       ┆ … ┆ 0.21      ┆ 9.857     ┆ false     ┆ true     │
# │ 762       ┆ SUB       ┆ CGK       ┆ 738       ┆ … ┆ 0.346     ┆ 10.941    ┆ false     ┆ true     │
# │ 763       ┆ CGK       ┆ SUB       ┆ 738       ┆ … ┆ 0.21      ┆ 9.857     ┆ false     ┆ true     │
# │ 764       ┆ SUB       ┆ CGK       ┆ 738       ┆ … ┆ 0.346     ┆ 10.941    ┆ false     ┆ true     │
# │ 771       ┆ CGK       ┆ DPS       ┆ 738       ┆ … ┆ 0.21      ┆ 13.294    ┆ false     ┆ true     │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 420       ┆ CZM       ┆ CUN       ┆ CNF       ┆ … ┆ null      ┆ null      ┆ true      ┆ true     │
# │ 450       ┆ CTM       ┆ CUN       ┆ CNF       ┆ … ┆ null      ┆ null      ┆ true      ┆ true     │
# │ 451       ┆ CUN       ┆ CTM       ┆ CNF       ┆ … ┆ null      ┆ null      ┆ true      ┆ true     │
# │ 474       ┆ CUN       ┆ MID       ┆ CNF       ┆ … ┆ null      ┆ null      ┆ true      ┆ true     │
# │ 475       ┆ MID       ┆ CUN       ┆ CNF       ┆ … ┆ null      ┆ null      ┆ true      ┆ true     │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
emissions_nu = emissions2.drop_nulls()
emissions_nu
# Out:
# shape: (283_132, 21)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ FLIGHT_NU ┆ DEPARTURE ┆ ARRIVAL_A ┆ AIRCRAFT_ ┆ … ┆ ESTIMATED ┆ ESTIMATED ┆ MISSING_R ┆ IS_OPERA │
# │ MBER      ┆ _AIRPORT  ┆ IRPORT    ┆ TYPE      ┆   ┆ _CO2_TAXI ┆ _CO2_TOTA ┆ EFERENCE_ ┆ TING     │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ _IN_TONNE ┆ L_TONNES  ┆ FLIGHT_TI ┆ ---      │
# │ i64       ┆ str       ┆ str       ┆ str       ┆   ┆ S         ┆ ---       ┆ MES       ┆ bool     │
# │           ┆           ┆           ┆           ┆   ┆ ---       ┆ f64       ┆ ---       ┆          │
# │           ┆           ┆           ┆           ┆   ┆ f64       ┆           ┆ bool      ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 761       ┆ CGK       ┆ SUB       ┆ 738       ┆ … ┆ 0.21      ┆ 9.857     ┆ false     ┆ true     │
# │ 762       ┆ SUB       ┆ CGK       ┆ 738       ┆ … ┆ 0.346     ┆ 10.941    ┆ false     ┆ true     │
# │ 763       ┆ CGK       ┆ SUB       ┆ 738       ┆ … ┆ 0.21      ┆ 9.857     ┆ false     ┆ true     │
# │ 764       ┆ SUB       ┆ CGK       ┆ 738       ┆ … ┆ 0.346     ┆ 10.941    ┆ false     ┆ true     │
# │ 771       ┆ CGK       ┆ DPS       ┆ 738       ┆ … ┆ 0.21      ┆ 13.294    ┆ false     ┆ true     │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 2330      ┆ KAN       ┆ ABV       ┆ 735       ┆ … ┆ 0.329     ┆ 5.413     ┆ false     ┆ true     │
# │ 2332      ┆ LOS       ┆ ABV       ┆ 735       ┆ … ┆ 0.281     ┆ 5.023     ┆ true      ┆ true     │
# │ 2333      ┆ ABV       ┆ LOS       ┆ 733       ┆ … ┆ 0.279     ┆ 3.501     ┆ true      ┆ true     │
# │ 2335      ┆ ABV       ┆ LOS       ┆ 733       ┆ … ┆ 0.279     ┆ 3.501     ┆ true      ┆ true     │
# │ 2337      ┆ MIU       ┆ ABV       ┆ 733       ┆ … ┆ 0.279     ┆ 4.772     ┆ true      ┆ true     │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
emissions_nu['MISSING_REFERENCE_FLIGHT_TIMES'].value_counts()
# Out:
# shape: (2, 2)
# ┌────────────────────────────────┬────────┐
# │ MISSING_REFERENCE_FLIGHT_TIMES ┆ count  │
# │ ---                            ┆ ---    │
# │ bool                           ┆ u32    │
# ╞════════════════════════════════╪════════╡
# │ true                           ┆ 39396  │
# │ false                          ┆ 243736 │
# └────────────────────────────────┴────────┘

# %%
#drop 'missing reference flight times' column, as only dropping around 1/8 of the data and the data is unreliable
emissions_nu1 = emissions_nu.filter(pl.col("MISSING_REFERENCE_FLIGHT_TIMES") == "false")
emissions_nu1
# Out:
# shape: (243_736, 21)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ FLIGHT_NU ┆ DEPARTURE ┆ ARRIVAL_A ┆ AIRCRAFT_ ┆ … ┆ ESTIMATED ┆ ESTIMATED ┆ MISSING_R ┆ IS_OPERA │
# │ MBER      ┆ _AIRPORT  ┆ IRPORT    ┆ TYPE      ┆   ┆ _CO2_TAXI ┆ _CO2_TOTA ┆ EFERENCE_ ┆ TING     │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ _IN_TONNE ┆ L_TONNES  ┆ FLIGHT_TI ┆ ---      │
# │ i64       ┆ str       ┆ str       ┆ str       ┆   ┆ S         ┆ ---       ┆ MES       ┆ bool     │
# │           ┆           ┆           ┆           ┆   ┆ ---       ┆ f64       ┆ ---       ┆          │
# │           ┆           ┆           ┆           ┆   ┆ f64       ┆           ┆ bool      ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 761       ┆ CGK       ┆ SUB       ┆ 738       ┆ … ┆ 0.21      ┆ 9.857     ┆ false     ┆ true     │
# │ 762       ┆ SUB       ┆ CGK       ┆ 738       ┆ … ┆ 0.346     ┆ 10.941    ┆ false     ┆ true     │
# │ 763       ┆ CGK       ┆ SUB       ┆ 738       ┆ … ┆ 0.21      ┆ 9.857     ┆ false     ┆ true     │
# │ 764       ┆ SUB       ┆ CGK       ┆ 738       ┆ … ┆ 0.346     ┆ 10.941    ┆ false     ┆ true     │
# │ 771       ┆ CGK       ┆ DPS       ┆ 738       ┆ … ┆ 0.21      ┆ 13.294    ┆ false     ┆ true     │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 306       ┆ JNB       ┆ LUN       ┆ 73W       ┆ … ┆ 0.257     ┆ 12.893    ┆ false     ┆ true     │
# │ 307       ┆ LUN       ┆ JNB       ┆ 73W       ┆ … ┆ 0.3       ┆ 14.197    ┆ false     ┆ true     │
# │ 524       ┆ DAR       ┆ NBO       ┆ 73W       ┆ … ┆ 0.389     ┆ 8.586     ┆ false     ┆ true     │
# │ 2329      ┆ ABV       ┆ KAN       ┆ 733       ┆ … ┆ 0.281     ┆ 7.865     ┆ false     ┆ true     │
# │ 2330      ┆ KAN       ┆ ABV       ┆ 735       ┆ … ┆ 0.329     ┆ 5.413     ┆ false     ┆ true     │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
emissions_nu2 = emissions_nu1.select('DEPARTURE_AIRPORT','ARRIVAL_AIRPORT','AIRCRAFT_TYPE','ESTIMATED_CO2_TOTAL_TONNES', 'SEATS').unique()
emissions_nu2
# Out:
# shape: (89_477, 5)
# ┌───────────────────┬─────────────────┬───────────────┬────────────────────────────┬───────┐
# │ DEPARTURE_AIRPORT ┆ ARRIVAL_AIRPORT ┆ AIRCRAFT_TYPE ┆ ESTIMATED_CO2_TOTAL_TONNES ┆ SEATS │
# │ ---               ┆ ---             ┆ ---           ┆ ---                        ┆ ---   │
# │ str               ┆ str             ┆ str           ┆ f64                        ┆ i64   │
# ╞═══════════════════╪═════════════════╪═══════════════╪════════════════════════════╪═══════╡
# │ NKG               ┆ PEK             ┆ 333           ┆ 30.06                      ┆ 301   │
# │ LYS               ┆ IST             ┆ 32Q           ┆ 21.986                     ┆ 182   │
# │ ZUH               ┆ SHA             ┆ 32A           ┆ 14.467                     ┆ 164   │
# │ SSA               ┆ GYN             ┆ E95           ┆ 10.952                     ┆ 118   │
# │ AAA               ┆ MKP             ┆ AT7           ┆ 0.847                      ┆ 70    │
# │ …                 ┆ …               ┆ …             ┆ …                          ┆ …     │
# │ IAH               ┆ TUL             ┆ E7W           ┆ 7.053                      ┆ 70    │
# │ RDU               ┆ IAD             ┆ 319           ┆ 6.439                      ┆ 126   │
# │ OVB               ┆ IKT             ┆ 73H           ┆ 16.15                      ┆ 176   │
# │ BOS               ┆ JFK             ┆ 320           ┆ 6.712                      ┆ 162   │
# │ SFO               ┆ ORD             ┆ 753           ┆ 47.576                     ┆ 234   │
# └───────────────────┴─────────────────┴───────────────┴────────────────────────────┴───────┘

# %%
airport_dictionary = {

    'Mumbai': ['BOM'],

    'London': ['LHR', 'LGW', 'LTN', 'STN'],

    'Paris': ['CDG', 'ORY', 'BVA'],

    'Hong Kong': ['HKG'],

    'Singapore': ['SIN'],

    'Shanghai': ['PVG', 'SHA'],

    'Dubai': ['DXB'],

    'Zürich': ['ZRH'],

    'Geneva': ['GVA'],

    'Aarhus': ['AAR'],

    'Sydney': ['SYD'],

    'Wroclaw': ['WRO'],

    'Budapest': ['BUD']

}

 

 
'''
target_codes = set()

    if city in airport_dictionary:

        target_codes.update(airport_dictionary[city])

'''
target_codes=set()

for city in airport_dictionary:
    target_codes.update(airport_dictionary[city])

filter_expression = (

    (pl.col("DEPARTURE_AIRPORT").is_in(target_codes)) |

    (pl.col("ARRIVAL_AIRPORT").is_in(target_codes))

)

# %%
filtered_emissions = emissions_nu2.filter(filter_expression)
matching_emissions=filtered_emissions.rename({'DEPARTURE_AIRPORT':'DEPCITY','ARRIVAL_AIRPORT':'ARRCITY'})
matching_emissions
# Out:
# shape: (12_708, 5)
# ┌─────────┬─────────┬───────────────┬────────────────────────────┬───────┐
# │ DEPCITY ┆ ARRCITY ┆ AIRCRAFT_TYPE ┆ ESTIMATED_CO2_TOTAL_TONNES ┆ SEATS │
# │ ---     ┆ ---     ┆ ---           ┆ ---                        ┆ ---   │
# │ str     ┆ str     ┆ str           ┆ f64                        ┆ i64   │
# ╞═════════╪═════════╪═══════════════╪════════════════════════════╪═══════╡
# │ ZUH     ┆ SHA     ┆ 32A           ┆ 14.467                     ┆ 164   │
# │ CDG     ┆ BER     ┆ 320           ┆ 11.276                     ┆ 186   │
# │ GVA     ┆ ZRH     ┆ 32N           ┆ 3.898                      ┆ 180   │
# │ DXB     ┆ CAN     ┆ 77W           ┆ 175.104                    ┆ 354   │
# │ NRT     ┆ PVG     ┆ 77W           ┆ 75.72                      ┆ 316   │
# │ …       ┆ …       ┆ …             ┆ …                          ┆ …     │
# │ CDG     ┆ MEX     ┆ 359           ┆ 178.002                    ┆ 292   │
# │ BUD     ┆ GLA     ┆ 32Q           ┆ 17.472                     ┆ 239   │
# │ GLA     ┆ DXB     ┆ 388           ┆ 243.519                    ┆ 491   │
# │ DXB     ┆ TRV     ┆ 738           ┆ 29.824                     ┆ 186   │
# │ PSA     ┆ BUD     ┆ 73H           ┆ 10.538                     ┆ 189   │
# └─────────┴─────────┴───────────────┴────────────────────────────┴───────┘

# %%
#print(matching_emissions.group_by(['DEPCITY','ARRCITY']).count().filter(pl.col('count')>1))
emissions_lookup=matching_emissions.unique(subset=['DEPCITY','ARRCITY'],keep='first')
emissions_lookup
# Out:
# shape: (4_081, 5)
# ┌─────────┬─────────┬───────────────┬────────────────────────────┬───────┐
# │ DEPCITY ┆ ARRCITY ┆ AIRCRAFT_TYPE ┆ ESTIMATED_CO2_TOTAL_TONNES ┆ SEATS │
# │ ---     ┆ ---     ┆ ---           ┆ ---                        ┆ ---   │
# │ str     ┆ str     ┆ str           ┆ f64                        ┆ i64   │
# ╞═════════╪═════════╪═══════════════╪════════════════════════════╪═══════╡
# │ VLC     ┆ LHR     ┆ 32A           ┆ 16.655                     ┆ 180   │
# │ GVA     ┆ SEN     ┆ 320           ┆ 10.376                     ┆ 186   │
# │ MAN     ┆ GVA     ┆ 73H           ┆ 11.816                     ┆ 189   │
# │ CUN     ┆ CDG     ┆ 77W           ┆ 229.715                    ┆ 472   │
# │ LHR     ┆ ORD     ┆ 777           ┆ 197.94                     ┆ 235   │
# │ …       ┆ …       ┆ …             ┆ …                          ┆ …     │
# │ BNE     ┆ HKG     ┆ 77W           ┆ 212.096                    ┆ 294   │
# │ LGW     ┆ AUA     ┆ 789           ┆ 143.446                    ┆ 345   │
# │ CTU     ┆ SHA     ┆ 330           ┆ 45.351                     ┆ 279   │
# │ SYD     ┆ JNB     ┆ 388           ┆ 510.906                    ┆ 485   │
# │ KMG     ┆ SHA     ┆ 737           ┆ 20.901                     ┆ 134   │
# └─────────┴─────────┴───────────────┴────────────────────────────┴───────┘

# %%
merge_df=final_df.join(emissions_lookup,on=['DEPCITY','ARRCITY'],how='left').unique().drop_nulls()

# %%
merge_df
# Out:
# shape: (41_811, 8)
# ┌─────────┬─────────┬──────────────┬─────────────┬─────────────┬─────────────┬─────────────┬───────┐
# │ DEPCITY ┆ ARRCITY ┆ SCHEDULED_DE ┆ SCHEDULED_A ┆ FLIGHT_DURA ┆ AIRCRAFT_TY ┆ ESTIMATED_C ┆ SEATS │
# │ ---     ┆ ---     ┆ PARTURE_DATE ┆ RRIVAL_DATE ┆ TION        ┆ PE          ┆ O2_TOTAL_TO ┆ ---   │
# │ str     ┆ str     ┆ _TIME_…      ┆ _TIME_LO…   ┆ ---         ┆ ---         ┆ NNES        ┆ i64   │
# │         ┆         ┆ ---          ┆ ---         ┆ duration[μs ┆ str         ┆ ---         ┆       │
# │         ┆         ┆ str          ┆ str         ┆ ]           ┆             ┆ f64         ┆       │
# ╞═════════╪═════════╪══════════════╪═════════════╪═════════════╪═════════════╪═════════════╪═══════╡
# │ KUL     ┆ HKG     ┆ 2025-12-05   ┆ 2025-12-05  ┆ 4h 10m      ┆ 333         ┆ 71.266      ┆ 317   │
# │         ┆         ┆ 17:50:00.000 ┆ 22:00:00.00 ┆             ┆             ┆             ┆       │
# │         ┆         ┆              ┆ 0           ┆             ┆             ┆             ┆       │
# │ HKG     ┆ KUL     ┆ 2025-12-12   ┆ 2025-12-12  ┆ 4h 5m       ┆ 738         ┆ 28.229      ┆ 160   │
# │         ┆         ┆ 08:30:00.000 ┆ 12:35:00.00 ┆             ┆             ┆             ┆       │
# │         ┆         ┆              ┆ 0           ┆             ┆             ┆             ┆       │
# │ SIN     ┆ HAN     ┆ 2025-12-06   ┆ 2025-12-06  ┆ 3h 35m      ┆ 321         ┆ 28.45       ┆ 184   │
# │         ┆         ┆ 13:05:00.000 ┆ 15:40:00.00 ┆             ┆             ┆             ┆       │
# │         ┆         ┆              ┆ 0           ┆             ┆             ┆             ┆       │
# │ SIN     ┆ SGN     ┆ 2025-12-14   ┆ 2025-12-14  ┆ 2h 10m      ┆ 321         ┆ 17.677      ┆ 220   │
# │         ┆         ┆ 17:30:00.000 ┆ 18:40:00.00 ┆             ┆             ┆             ┆       │
# │         ┆         ┆              ┆ 0           ┆             ┆             ┆             ┆       │
# │ SHA     ┆ TAO     ┆ 2025-12-08   ┆ 2025-12-09  ┆ 1h 35m      ┆ 738         ┆ 10.928      ┆ 175   │
# │         ┆         ┆ 23:15:00.000 ┆ 00:50:00.00 ┆             ┆             ┆             ┆       │
# │         ┆         ┆              ┆ 0           ┆             ┆             ┆             ┆       │
# │ …       ┆ …       ┆ …            ┆ …           ┆ …           ┆ …           ┆ …           ┆ …     │
# │ SYD     ┆ CAN     ┆ 2025-12-12   ┆ 2025-12-12  ┆ 9h 35m      ┆ 330         ┆ 179.182     ┆ 283   │
# │         ┆         ┆ 11:25:00.000 ┆ 18:00:00.00 ┆             ┆             ┆             ┆       │
# │         ┆         ┆              ┆ 0           ┆             ┆             ┆             ┆       │
# │ KUL     ┆ SIN     ┆ 2025-12-10   ┆ 2025-12-10  ┆ 1h 15m      ┆ 359         ┆ 15.021      ┆ 303   │
# │         ┆         ┆ 09:05:00.000 ┆ 10:20:00.00 ┆             ┆             ┆             ┆       │
# │         ┆         ┆              ┆ 0           ┆             ┆             ┆             ┆       │
# │ SYD     ┆ ADL     ┆ 2025-12-08   ┆ 2025-12-08  ┆ 2h 10m      ┆ 320         ┆ 14.228      ┆ 186   │
# │         ┆         ┆ 11:00:00.000 ┆ 12:40:00.00 ┆             ┆             ┆             ┆       │
# │         ┆         ┆              ┆ 0           ┆             ┆             ┆             ┆       │
# │ JLR     ┆ BOM     ┆ 2025-12-15   ┆ 2025-12-15  ┆ 1h 50m      ┆ 32N         ┆ 9.03        ┆ 186   │
# │         ┆         ┆ 17:30:00.000 ┆ 19:20:00.00 ┆             ┆             ┆             ┆       │
# │         ┆         ┆              ┆ 0           ┆             ┆             ┆             ┆       │
# │ SHA     ┆ CKG     ┆ 2025-12-11   ┆ 2025-12-11  ┆ 3h 15m      ┆ 333         ┆ 47.982      ┆ 298   │
# │         ┆         ┆ 13:15:00.000 ┆ 16:30:00.00 ┆             ┆             ┆             ┆       │
# │         ┆         ┆              ┆ 0           ┆             ┆             ┆             ┆       │
# └─────────┴─────────┴──────────────┴─────────────┴─────────────┴─────────────┴─────────────┴───────┘

# %%
merge_df = merge_df.with_columns(
    pl.col("SCHEDULED_ARRIVAL_DATE_TIME_LOCAL")
    .str.to_datetime(strict=False),
    pl.col("SCHEDULED_DEPARTURE_DATE_TIME_LOCAL")
    .str.to_datetime(strict=False)
)
merge_df
# Out:
# shape: (41_811, 8)
# ┌─────────┬─────────┬──────────────┬─────────────┬─────────────┬─────────────┬─────────────┬───────┐
# │ DEPCITY ┆ ARRCITY ┆ SCHEDULED_DE ┆ SCHEDULED_A ┆ FLIGHT_DURA ┆ AIRCRAFT_TY ┆ ESTIMATED_C ┆ SEATS │
# │ ---     ┆ ---     ┆ PARTURE_DATE ┆ RRIVAL_DATE ┆ TION        ┆ PE          ┆ O2_TOTAL_TO ┆ ---   │
# │ str     ┆ str     ┆ _TIME_…      ┆ _TIME_LO…   ┆ ---         ┆ ---         ┆ NNES        ┆ i64   │
# │         ┆         ┆ ---          ┆ ---         ┆ duration[μs ┆ str         ┆ ---         ┆       │
# │         ┆         ┆ datetime[μs] ┆ datetime[μs ┆ ]           ┆             ┆ f64         ┆       │
# │         ┆         ┆              ┆ ]           ┆             ┆             ┆             ┆       │
# ╞═════════╪═════════╪══════════════╪═════════════╪═════════════╪═════════════╪═════════════╪═══════╡
# │ KUL     ┆ HKG     ┆ 2025-12-05   ┆ 2025-12-05  ┆ 4h 10m      ┆ 333         ┆ 71.266      ┆ 317   │
# │         ┆         ┆ 17:50:00     ┆ 22:00:00    ┆             ┆             ┆             ┆       │
# │ HKG     ┆ KUL     ┆ 2025-12-12   ┆ 2025-12-12  ┆ 4h 5m       ┆ 738         ┆ 28.229      ┆ 160   │
# │         ┆         ┆ 08:30:00     ┆ 12:35:00    ┆             ┆             ┆             ┆       │
# │ SIN     ┆ HAN     ┆ 2025-12-06   ┆ 2025-12-06  ┆ 3h 35m      ┆ 321         ┆ 28.45       ┆ 184   │
# │         ┆         ┆ 13:05:00     ┆ 15:40:00    ┆             ┆             ┆             ┆       │
# │ SIN     ┆ SGN     ┆ 2025-12-14   ┆ 2025-12-14  ┆ 2h 10m      ┆ 321         ┆ 17.677      ┆ 220   │
# │         ┆         ┆ 17:30:00     ┆ 18:40:00    ┆             ┆             ┆             ┆       │
# │ SHA     ┆ TAO     ┆ 2025-12-08   ┆ 2025-12-09  ┆ 1h 35m      ┆ 738         ┆ 10.928      ┆ 175   │
# │         ┆         ┆ 23:15:00     ┆ 00:50:00    ┆             ┆             ┆             ┆       │
# │ …       ┆ …       ┆ …            ┆ …           ┆ …           ┆ …           ┆ …           ┆ …     │
# │ SYD     ┆ CAN     ┆ 2025-12-12   ┆ 2025-12-12  ┆ 9h 35m      ┆ 330         ┆ 179.182     ┆ 283   │
# │         ┆         ┆ 11:25:00     ┆ 18:00:00    ┆             ┆             ┆             ┆       │
# │ KUL     ┆ SIN     ┆ 2025-12-10   ┆ 2025-12-10  ┆ 1h 15m      ┆ 359         ┆ 15.021      ┆ 303   │
# │         ┆         ┆ 09:05:00     ┆ 10:20:00    ┆             ┆             ┆             ┆       │
# │ SYD     ┆ ADL     ┆ 2025-12-08   ┆ 2025-12-08  ┆ 2h 10m      ┆ 320         ┆ 14.228      ┆ 186   │
# │         ┆         ┆ 11:00:00     ┆ 12:40:00    ┆             ┆             ┆             ┆       │
# │ JLR     ┆ BOM     ┆ 2025-12-15   ┆ 2025-12-15  ┆ 1h 50m      ┆ 32N         ┆ 9.03        ┆ 186   │
# │         ┆         ┆ 17:30:00     ┆ 19:20:00    ┆             ┆             ┆             ┆       │
# │ SHA     ┆ CKG     ┆ 2025-12-11   ┆ 2025-12-11  ┆ 3h 15m      ┆ 333         ┆ 47.982      ┆ 298   │
# │         ┆         ┆ 13:15:00     ┆ 16:30:00    ┆             ┆             ┆             ┆       │
# └─────────┴─────────┴──────────────┴─────────────┴─────────────┴─────────────┴─────────────┴───────┘

# %%
merge_df = merge_df.with_columns(
    (pl.col("ESTIMATED_CO2_TOTAL_TONNES") / pl.col("SEATS")).alias("EMISSION_PER_SEAT")
)
merge_df
# Out:
# shape: (41_811, 9)
# ┌─────────┬─────────┬─────────────┬─────────────┬───┬────────────┬────────────┬───────┬────────────┐
# │ DEPCITY ┆ ARRCITY ┆ SCHEDULED_D ┆ SCHEDULED_A ┆ … ┆ AIRCRAFT_T ┆ ESTIMATED_ ┆ SEATS ┆ EMISSION_P │
# │ ---     ┆ ---     ┆ EPARTURE_DA ┆ RRIVAL_DATE ┆   ┆ YPE        ┆ CO2_TOTAL_ ┆ ---   ┆ ER_SEAT    │
# │ str     ┆ str     ┆ TE_TIME_…   ┆ _TIME_LO…   ┆   ┆ ---        ┆ TONNES     ┆ i64   ┆ ---        │
# │         ┆         ┆ ---         ┆ ---         ┆   ┆ str        ┆ ---        ┆       ┆ f64        │
# │         ┆         ┆ datetime[μs ┆ datetime[μs ┆   ┆            ┆ f64        ┆       ┆            │
# │         ┆         ┆ ]           ┆ ]           ┆   ┆            ┆            ┆       ┆            │
# ╞═════════╪═════════╪═════════════╪═════════════╪═══╪════════════╪════════════╪═══════╪════════════╡
# │ KUL     ┆ HKG     ┆ 2025-12-05  ┆ 2025-12-05  ┆ … ┆ 333        ┆ 71.266     ┆ 317   ┆ 0.224814   │
# │         ┆         ┆ 17:50:00    ┆ 22:00:00    ┆   ┆            ┆            ┆       ┆            │
# │ HKG     ┆ KUL     ┆ 2025-12-12  ┆ 2025-12-12  ┆ … ┆ 738        ┆ 28.229     ┆ 160   ┆ 0.176431   │
# │         ┆         ┆ 08:30:00    ┆ 12:35:00    ┆   ┆            ┆            ┆       ┆            │
# │ SIN     ┆ HAN     ┆ 2025-12-06  ┆ 2025-12-06  ┆ … ┆ 321        ┆ 28.45      ┆ 184   ┆ 0.15462    │
# │         ┆         ┆ 13:05:00    ┆ 15:40:00    ┆   ┆            ┆            ┆       ┆            │
# │ SIN     ┆ SGN     ┆ 2025-12-14  ┆ 2025-12-14  ┆ … ┆ 321        ┆ 17.677     ┆ 220   ┆ 0.08035    │
# │         ┆         ┆ 17:30:00    ┆ 18:40:00    ┆   ┆            ┆            ┆       ┆            │
# │ SHA     ┆ TAO     ┆ 2025-12-08  ┆ 2025-12-09  ┆ … ┆ 738        ┆ 10.928     ┆ 175   ┆ 0.062446   │
# │         ┆         ┆ 23:15:00    ┆ 00:50:00    ┆   ┆            ┆            ┆       ┆            │
# │ …       ┆ …       ┆ …           ┆ …           ┆ … ┆ …          ┆ …          ┆ …     ┆ …          │
# │ SYD     ┆ CAN     ┆ 2025-12-12  ┆ 2025-12-12  ┆ … ┆ 330        ┆ 179.182    ┆ 283   ┆ 0.633152   │
# │         ┆         ┆ 11:25:00    ┆ 18:00:00    ┆   ┆            ┆            ┆       ┆            │
# │ KUL     ┆ SIN     ┆ 2025-12-10  ┆ 2025-12-10  ┆ … ┆ 359        ┆ 15.021     ┆ 303   ┆ 0.049574   │
# │         ┆         ┆ 09:05:00    ┆ 10:20:00    ┆   ┆            ┆            ┆       ┆            │
# │ SYD     ┆ ADL     ┆ 2025-12-08  ┆ 2025-12-08  ┆ … ┆ 320        ┆ 14.228     ┆ 186   ┆ 0.076495   │
# │         ┆         ┆ 11:00:00    ┆ 12:40:00    ┆   ┆            ┆            ┆       ┆            │
# │ JLR     ┆ BOM     ┆ 2025-12-15  ┆ 2025-12-15  ┆ … ┆ 32N        ┆ 9.03       ┆ 186   ┆ 0.048548   │
# │         ┆         ┆ 17:30:00    ┆ 19:20:00    ┆   ┆            ┆            ┆       ┆            │
# │ SHA     ┆ CKG     ┆ 2025-12-11  ┆ 2025-12-11  ┆ … ┆ 333        ┆ 47.982     ┆ 298   ┆ 0.161013   │
# │         ┆         ┆ 13:15:00    ┆ 16:30:00    ┆   ┆            ┆            ┆       ┆            │
# └─────────┴─────────┴─────────────┴─────────────┴───┴────────────┴────────────┴───────┴────────────┘

# %%
def departure_time(data,city0,city1,arrive_before_time):

    # 1. Calculate the arrival time for all flights # and filter out flights that don't match our criteria. 
    best_dept_flight = data.with_columns((pl.col("SCHEDULED_DEPARTURE_DATE_TIME_LOCAL") + pl.col("FLIGHT_DURATION")).alias("SCHEDULED_ARRIVAL_DATE_TIME_LOCAL")).filter((pl.col("DEPCITY") == city0) & (pl.col("ARRCITY") == city1) & (pl.col("SCHEDULED_ARRIVAL_DATE_TIME_LOCAL") < arrive_before_time)).sort("SCHEDULED_DEPARTURE_DATE_TIME_LOCAL", descending=True ).head(1) # 3. Select the top one return best_flight
    #relevant_data = data.filter((pl.col("DEPCITY") == city0) & (pl.col("ARRCITY")) == city1)& (arrive_before_time >pl.col('SCHEDULED_ARRIVAL_DATE_TIME_LOCAL'))
    
    return best_dept_flight['SCHEDULED_DEPARTURE_DATE_TIME_LOCAL','EMISSION_PER_SEAT']

departure_time(merge_df,'SIN','HKG',datetime.datetime(2025,12,11,11,0,0))
# Out:
# shape: (1, 2)
# ┌─────────────────────────────────┬───────────────────┐
# │ SCHEDULED_DEPARTURE_DATE_TIME_… ┆ EMISSION_PER_SEAT │
# │ ---                             ┆ ---               │
# │ datetime[μs]                    ┆ f64               │
# ╞═════════════════════════════════╪═══════════════════╡
# │ 2025-12-11 01:25:00             ┆ 0.344023          │
# └─────────────────────────────────┴───────────────────┘

# %%
def arrival_time(data,city0,city1,meeting_end):

    # 1. Calculate the departure time for all flights # and filter out flights that don't match our criteria. 
    best_arv_flight = data.with_columns((pl.col("SCHEDULED_DEPARTURE_DATE_TIME_LOCAL") + pl.col("FLIGHT_DURATION")).alias("SCHEDULED_ARRIVAL_DATE_TIME_LOCAL")).filter((pl.col("DEPCITY") == city1) & (pl.col("ARRCITY") == city0) & (pl.col("SCHEDULED_DEPARTURE_DATE_TIME_LOCAL") > meeting_end)).sort("SCHEDULED_ARRIVAL_DATE_TIME_LOCAL", descending=False).head(1) # 3. Select the top one return best_flight
    #relevant_data = data.filter((pl.col("DEPCITY") == city0) & (pl.col("ARRCITY")) == city1)& (arrive_before_time >pl.col('SCHEDULED_ARRIVAL_DATE_TIME_LOCAL'))
    
    return best_arv_flight['SCHEDULED_ARRIVAL_DATE_TIME_LOCAL','EMISSION_PER_SEAT']

arrival_time(merge_df,'SIN','HKG',datetime.datetime(2025,12,12,14,0,0))
# Out:
# shape: (1, 2)
# ┌─────────────────────────────────┬───────────────────┐
# │ SCHEDULED_ARRIVAL_DATE_TIME_LO… ┆ EMISSION_PER_SEAT │
# │ ---                             ┆ ---               │
# │ datetime[μs]                    ┆ f64               │
# ╞═════════════════════════════════╪═══════════════════╡
# │ 2025-12-12 18:15:00             ┆ 0.198329          │
# └─────────────────────────────────┴───────────────────┘

# %%
type(merge_df)
# Out:
# polars.dataframe.frame.DataFrame

# %%
#converting datetime back to str so can be saved as csv file

merge_df = merge_df.with_columns([
    pl.col("SCHEDULED_ARRIVAL_DATE_TIME_LOCAL").dt.strftime("%Y-%m-%d %H:%M:%S").alias("SCHEDULED_ARRIVAL_DATE_TIME_LOCAL"),
    pl.col("SCHEDULED_DEPARTURE_DATE_TIME_LOCAL").dt.strftime("%Y-%m-%d %H:%M:%S").alias("SCHEDULED_DEPARTURE_DATE_TIME_LOCAL")
])
merge_df
# Out:
# shape: (41_811, 9)
# ┌─────────┬─────────┬─────────────┬─────────────┬───┬────────────┬────────────┬───────┬────────────┐
# │ DEPCITY ┆ ARRCITY ┆ SCHEDULED_D ┆ SCHEDULED_A ┆ … ┆ AIRCRAFT_T ┆ ESTIMATED_ ┆ SEATS ┆ EMISSION_P │
# │ ---     ┆ ---     ┆ EPARTURE_DA ┆ RRIVAL_DATE ┆   ┆ YPE        ┆ CO2_TOTAL_ ┆ ---   ┆ ER_SEAT    │
# │ str     ┆ str     ┆ TE_TIME_…   ┆ _TIME_LO…   ┆   ┆ ---        ┆ TONNES     ┆ i64   ┆ ---        │
# │         ┆         ┆ ---         ┆ ---         ┆   ┆ str        ┆ ---        ┆       ┆ f64        │
# │         ┆         ┆ str         ┆ str         ┆   ┆            ┆ f64        ┆       ┆            │
# ╞═════════╪═════════╪═════════════╪═════════════╪═══╪════════════╪════════════╪═══════╪════════════╡
# │ KUL     ┆ HKG     ┆ 2025-12-05  ┆ 2025-12-05  ┆ … ┆ 333        ┆ 71.266     ┆ 317   ┆ 0.224814   │
# │         ┆         ┆ 17:50:00    ┆ 22:00:00    ┆   ┆            ┆            ┆       ┆            │
# │ HKG     ┆ KUL     ┆ 2025-12-12  ┆ 2025-12-12  ┆ … ┆ 738        ┆ 28.229     ┆ 160   ┆ 0.176431   │
# │         ┆         ┆ 08:30:00    ┆ 12:35:00    ┆   ┆            ┆            ┆       ┆            │
# │ SIN     ┆ HAN     ┆ 2025-12-06  ┆ 2025-12-06  ┆ … ┆ 321        ┆ 28.45      ┆ 184   ┆ 0.15462    │
# │         ┆         ┆ 13:05:00    ┆ 15:40:00    ┆   ┆            ┆            ┆       ┆            │
# │ SIN     ┆ SGN     ┆ 2025-12-14  ┆ 2025-12-14  ┆ … ┆ 321        ┆ 17.677     ┆ 220   ┆ 0.08035    │
# │         ┆         ┆ 17:30:00    ┆ 18:40:00    ┆   ┆            ┆            ┆       ┆            │
# │ SHA     ┆ TAO     ┆ 2025-12-08  ┆ 2025-12-09  ┆ … ┆ 738        ┆ 10.928     ┆ 175   ┆ 0.062446   │
# │         ┆         ┆ 23:15:00    ┆ 00:50:00    ┆   ┆            ┆            ┆       ┆            │
# │ …       ┆ …       ┆ …           ┆ …           ┆ … ┆ …          ┆ …          ┆ …     ┆ …          │
# │ SYD     ┆ CAN     ┆ 2025-12-12  ┆ 2025-12-12  ┆ … ┆ 330        ┆ 179.182    ┆ 283   ┆ 0.633152   │
# │         ┆         ┆ 11:25:00    ┆ 18:00:00    ┆   ┆            ┆            ┆       ┆            │
# │ KUL     ┆ SIN     ┆ 2025-12-10  ┆ 2025-12-10  ┆ … ┆ 359        ┆ 15.021     ┆ 303   ┆ 0.049574   │
# │         ┆         ┆ 09:05:00    ┆ 10:20:00    ┆   ┆            ┆            ┆       ┆            │
# │ SYD     ┆ ADL     ┆ 2025-12-08  ┆ 2025-12-08  ┆ … ┆ 320        ┆ 14.228     ┆ 186   ┆ 0.076495   │
# │         ┆         ┆ 11:00:00    ┆ 12:40:00    ┆   ┆            ┆            ┆       ┆            │
# │ JLR     ┆ BOM     ┆ 2025-12-15  ┆ 2025-12-15  ┆ … ┆ 32N        ┆ 9.03       ┆ 186   ┆ 0.048548   │
# │         ┆         ┆ 17:30:00    ┆ 19:20:00    ┆   ┆            ┆            ┆       ┆            │
# │ SHA     ┆ CKG     ┆ 2025-12-11  ┆ 2025-12-11  ┆ … ┆ 333        ┆ 47.982     ┆ 298   ┆ 0.161013   │
# │         ┆         ┆ 13:15:00    ┆ 16:30:00    ┆   ┆            ┆            ┆       ┆            │
# └─────────┴─────────┴─────────────┴─────────────┴───┴────────────┴────────────┴───────┴────────────┘

# %%
merge_df = merge_df.with_columns(
    pl.format(
        "{}h {}m",
        (pl.col("FLIGHT_DURATION").dt.total_minutes() // 60),
        (pl.col("FLIGHT_DURATION").dt.total_minutes() % 60),
    ).alias("FLIGHT_DURATION_STR")
)


merge_df
# Out:
# shape: (41_811, 10)
# ┌─────────┬─────────┬─────────────┬─────────────┬───┬────────────┬───────┬────────────┬────────────┐
# │ DEPCITY ┆ ARRCITY ┆ SCHEDULED_D ┆ SCHEDULED_A ┆ … ┆ ESTIMATED_ ┆ SEATS ┆ EMISSION_P ┆ FLIGHT_DUR │
# │ ---     ┆ ---     ┆ EPARTURE_DA ┆ RRIVAL_DATE ┆   ┆ CO2_TOTAL_ ┆ ---   ┆ ER_SEAT    ┆ ATION_STR  │
# │ str     ┆ str     ┆ TE_TIME_…   ┆ _TIME_LO…   ┆   ┆ TONNES     ┆ i64   ┆ ---        ┆ ---        │
# │         ┆         ┆ ---         ┆ ---         ┆   ┆ ---        ┆       ┆ f64        ┆ str        │
# │         ┆         ┆ str         ┆ str         ┆   ┆ f64        ┆       ┆            ┆            │
# ╞═════════╪═════════╪═════════════╪═════════════╪═══╪════════════╪═══════╪════════════╪════════════╡
# │ KUL     ┆ HKG     ┆ 2025-12-05  ┆ 2025-12-05  ┆ … ┆ 71.266     ┆ 317   ┆ 0.224814   ┆ 4h 10m     │
# │         ┆         ┆ 17:50:00    ┆ 22:00:00    ┆   ┆            ┆       ┆            ┆            │
# │ HKG     ┆ KUL     ┆ 2025-12-12  ┆ 2025-12-12  ┆ … ┆ 28.229     ┆ 160   ┆ 0.176431   ┆ 4h 5m      │
# │         ┆         ┆ 08:30:00    ┆ 12:35:00    ┆   ┆            ┆       ┆            ┆            │
# │ SIN     ┆ HAN     ┆ 2025-12-06  ┆ 2025-12-06  ┆ … ┆ 28.45      ┆ 184   ┆ 0.15462    ┆ 3h 35m     │
# │         ┆         ┆ 13:05:00    ┆ 15:40:00    ┆   ┆            ┆       ┆            ┆            │
# │ SIN     ┆ SGN     ┆ 2025-12-14  ┆ 2025-12-14  ┆ … ┆ 17.677     ┆ 220   ┆ 0.08035    ┆ 2h 10m     │
# │         ┆         ┆ 17:30:00    ┆ 18:40:00    ┆   ┆            ┆       ┆            ┆            │
# │ SHA     ┆ TAO     ┆ 2025-12-08  ┆ 2025-12-09  ┆ … ┆ 10.928     ┆ 175   ┆ 0.062446   ┆ 1h 35m     │
# │         ┆         ┆ 23:15:00    ┆ 00:50:00    ┆   ┆            ┆       ┆            ┆            │
# │ …       ┆ …       ┆ …           ┆ …           ┆ … ┆ …          ┆ …     ┆ …          ┆ …          │
# │ SYD     ┆ CAN     ┆ 2025-12-12  ┆ 2025-12-12  ┆ … ┆ 179.182    ┆ 283   ┆ 0.633152   ┆ 9h 35m     │
# │         ┆         ┆ 11:25:00    ┆ 18:00:00    ┆   ┆            ┆       ┆            ┆            │
# │ KUL     ┆ SIN     ┆ 2025-12-10  ┆ 2025-12-10  ┆ … ┆ 15.021     ┆ 303   ┆ 0.049574   ┆ 1h 15m     │
# │         ┆         ┆ 09:05:00    ┆ 10:20:00    ┆   ┆            ┆       ┆            ┆            │
# │ SYD     ┆ ADL     ┆ 2025-12-08  ┆ 2025-12-08  ┆ … ┆ 14.228     ┆ 186   ┆ 0.076495   ┆ 2h 10m     │
# │         ┆         ┆ 11:00:00    ┆ 12:40:00    ┆   ┆            ┆       ┆            ┆            │
# │ JLR     ┆ BOM     ┆ 2025-12-15  ┆ 2025-12-15  ┆ … ┆ 9.03       ┆ 186   ┆ 0.048548   ┆ 1h 50m     │
# │         ┆         ┆ 17:30:00    ┆ 19:20:00    ┆   ┆            ┆       ┆            ┆            │
# │ SHA     ┆ CKG     ┆ 2025-12-11  ┆ 2025-12-11  ┆ … ┆ 47.982     ┆ 298   ┆ 0.161013   ┆ 3h 15m     │
# │         ┆         ┆ 13:15:00    ┆ 16:30:00    ┆   ┆            ┆       ┆            ┆            │
# └─────────┴─────────┴─────────────┴─────────────┴───┴────────────┴───────┴────────────┴────────────┘

# %%
merge_df.select(["FLIGHT_DURATION", "FLIGHT_DURATION_STR"]).head()
print(merge_df.schema)  # FLIGHT_DURATION_STR -> Utf8
# Out:
# Schema({'DEPCITY': String, 'ARRCITY': String, 'SCHEDULED_DEPARTURE_DATE_TIME_LOCAL': String, 'SCHEDULED_ARRIVAL_DATE_TIME_LOCAL': String, 'FLIGHT_DURATION': Duration(time_unit='us'), 'AIRCRAFT_TYPE': String, 'ESTIMATED_CO2_TOTAL_TONNES': Float64, 'SEATS': Int64, 'EMISSION_PER_SEAT': Float64, 'FLIGHT_DURATION_STR': String})

# %%
merge_df = merge_df.with_columns(
    pl.format(
        "{}h {}m",
        (pl.col("FLIGHT_DURATION").dt.total_minutes() // 60),
        (pl.col("FLIGHT_DURATION").dt.total_minutes() % 60),
    ).alias("FLIGHT_DURATION")  # same name → replaces old one
)

# %%
merge_df
# Out:
# shape: (41_811, 10)
# ┌─────────┬─────────┬─────────────┬─────────────┬───┬────────────┬───────┬────────────┬────────────┐
# │ DEPCITY ┆ ARRCITY ┆ SCHEDULED_D ┆ SCHEDULED_A ┆ … ┆ ESTIMATED_ ┆ SEATS ┆ EMISSION_P ┆ FLIGHT_DUR │
# │ ---     ┆ ---     ┆ EPARTURE_DA ┆ RRIVAL_DATE ┆   ┆ CO2_TOTAL_ ┆ ---   ┆ ER_SEAT    ┆ ATION_STR  │
# │ str     ┆ str     ┆ TE_TIME_…   ┆ _TIME_LO…   ┆   ┆ TONNES     ┆ i64   ┆ ---        ┆ ---        │
# │         ┆         ┆ ---         ┆ ---         ┆   ┆ ---        ┆       ┆ f64        ┆ str        │
# │         ┆         ┆ str         ┆ str         ┆   ┆ f64        ┆       ┆            ┆            │
# ╞═════════╪═════════╪═════════════╪═════════════╪═══╪════════════╪═══════╪════════════╪════════════╡
# │ KUL     ┆ HKG     ┆ 2025-12-05  ┆ 2025-12-05  ┆ … ┆ 71.266     ┆ 317   ┆ 0.224814   ┆ 4h 10m     │
# │         ┆         ┆ 17:50:00    ┆ 22:00:00    ┆   ┆            ┆       ┆            ┆            │
# │ HKG     ┆ KUL     ┆ 2025-12-12  ┆ 2025-12-12  ┆ … ┆ 28.229     ┆ 160   ┆ 0.176431   ┆ 4h 5m      │
# │         ┆         ┆ 08:30:00    ┆ 12:35:00    ┆   ┆            ┆       ┆            ┆            │
# │ SIN     ┆ HAN     ┆ 2025-12-06  ┆ 2025-12-06  ┆ … ┆ 28.45      ┆ 184   ┆ 0.15462    ┆ 3h 35m     │
# │         ┆         ┆ 13:05:00    ┆ 15:40:00    ┆   ┆            ┆       ┆            ┆            │
# │ SIN     ┆ SGN     ┆ 2025-12-14  ┆ 2025-12-14  ┆ … ┆ 17.677     ┆ 220   ┆ 0.08035    ┆ 2h 10m     │
# │         ┆         ┆ 17:30:00    ┆ 18:40:00    ┆   ┆            ┆       ┆            ┆            │
# │ SHA     ┆ TAO     ┆ 2025-12-08  ┆ 2025-12-09  ┆ … ┆ 10.928     ┆ 175   ┆ 0.062446   ┆ 1h 35m     │
# │         ┆         ┆ 23:15:00    ┆ 00:50:00    ┆   ┆            ┆       ┆            ┆            │
# │ …       ┆ …       ┆ …           ┆ …           ┆ … ┆ …          ┆ …     ┆ …          ┆ …          │
# │ SYD     ┆ CAN     ┆ 2025-12-12  ┆ 2025-12-12  ┆ … ┆ 179.182    ┆ 283   ┆ 0.633152   ┆ 9h 35m     │
# │         ┆         ┆ 11:25:00    ┆ 18:00:00    ┆   ┆            ┆       ┆            ┆            │
# │ KUL     ┆ SIN     ┆ 2025-12-10  ┆ 2025-12-10  ┆ … ┆ 15.021     ┆ 303   ┆ 0.049574   ┆ 1h 15m     │
# │         ┆         ┆ 09:05:00    ┆ 10:20:00    ┆   ┆            ┆       ┆            ┆            │
# │ SYD     ┆ ADL     ┆ 2025-12-08  ┆ 2025-12-08  ┆ … ┆ 14.228     ┆ 186   ┆ 0.076495   ┆ 2h 10m     │
# │         ┆         ┆ 11:00:00    ┆ 12:40:00    ┆   ┆            ┆       ┆            ┆            │
# │ JLR     ┆ BOM     ┆ 2025-12-15  ┆ 2025-12-15  ┆ … ┆ 9.03       ┆ 186   ┆ 0.048548   ┆ 1h 50m     │
# │         ┆         ┆ 17:30:00    ┆ 19:20:00    ┆   ┆            ┆       ┆            ┆            │
# │ SHA     ┆ CKG     ┆ 2025-12-11  ┆ 2025-12-11  ┆ … ┆ 47.982     ┆ 298   ┆ 0.161013   ┆ 3h 15m     │
# │         ┆         ┆ 13:15:00    ┆ 16:30:00    ┆   ┆            ┆       ┆            ┆            │
# └─────────┴─────────┴─────────────┴─────────────┴───┴────────────┴───────┴────────────┴────────────┘

# %%
from pathlib import Path

out_dir = Path("/Users/ankithrangan/Desktop/ChallengeData")
out_dir.mkdir(parents=True, exist_ok=True)  # create the folder if missing

merge_df.write_csv(out_dir /"merged_data.csv")
